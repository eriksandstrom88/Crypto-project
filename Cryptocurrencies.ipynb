# %% [markdown]
# Project to examine trends in Cryptocurrencies

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
import json

# Import API key
from api_keys import nomics_key
from api_keys2 import alvan_key
from gold_api import gold_api
from bls_key import bls_key

# %% [markdown]
# Extract Cryptocurrency historical price data

# %%
# Create start and end dates for queries since the API goes from daily data to weekly data if you query more than a month
# and there is no parameter that allows you to change the interval
years = ['2013','2014','2015','2016','2017','2018','2019','2020','2021']
days_per_month = {'01':'31','02':'28','03':'31','04':'30','05':'31','06':'30','07':'31','08':'31','09':'30','10':'31','11':'30','12':'31'}
btc_end_dates = []
btc_start_dates = []
for year in years:
    for key, values in days_per_month.items():
        btc_end_dates.append(f'{year}-{key}-{values}')
        btc_start_dates.append(f'{year}-{key}-01')
btc_end_dates = btc_end_dates[1:97] 
btc_start_dates = btc_start_dates[1:97]
btc_intervals = dict(zip(btc_start_dates, btc_end_dates))

# %%
# Query for Bitcoin data from 2/1/2013 to 1/31/2021
url = 'https://api.nomics.com/v1'
btc_timestamps = []
btc_prices = []
for key, value in btc_intervals.items():
    query_url = f'{url}/currencies/sparkline?key={nomics_key}&ids=BTC&start={key}T00%3A00%3A00Z&end={value}T00%3A00%3A00Z&interval=1d'
    data = requests.get(query_url)
    day_price = data.json()
    btc_timestamps.extend(day_price[0]['timestamps'])
    btc_prices.extend(day_price[0]['prices'])

# %%
# Remove some of the date coding from the BTC timestamps
btc_timestamps[:] = [s.replace('00:00:00Z','') for s in btc_timestamps]

# %%
btc_timestamps[:] = [s.replace('T','') for s in btc_timestamps]

# %%
# Make lists of weekly BTC prices and dates for analysis with gold
crypto_weekly_dates = []
crypto_weekly_prices = []
c_index = 0
for c in range(417):
    crypto_weekly_dates.append(btc_timestamps[c_index])
    crypto_weekly_prices.append(btc_prices[c_index])
    c_index = (c+1)*7

# %%
#create a dataframe to hold the crypto date and price data
crypto_dict = {'Date':btc_timestamps, 'BTC Price':btc_prices}
crypto_df = pd.DataFrame(crypto_dict)
crypto_df.to_csv('Crypto_Prices.csv')

# %% [markdown]
# EXTRACT STOCK DATA

# %%
# Query for DJIA and NDAQ daily stock data
# tickers = ['DJI','NDAQ','SWTX']
# stock_url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=SWTX&datatype=json&apikey={alvan_key}'
# stock_pull = requests.get(stock_url)
# dji_json = stock_pull.json()
# dji_json

# %% [markdown]
# EXTRACT GOLD DATA

# %%
# Create weekly list of dates for query
gold_dates_daily = [s.replace('-','') for s in btc_timestamps]

# %%
gold_dates_weekly = []
day_index = 0
for w in range(417):
    gold_dates_weekly.append(gold_dates_daily[day_index])
    day_index = (w+1)*7

# %%
# gold_dates_test = gold_dates_weekly[0:5]
# gold_dates_test
len(gold_dates_weekly)
# Out:
# 417

# %%
# Extract Gold Price Data
# import http.client
# import mimetypes
# weekly_gold_price = []
# gold_24h_chg_pct = []
# conn=http.client.HTTPSConnection('www.goldapi.io')
# payload = ''
# headers = {'x-access-token':gold_api, 'Content_Type':'application/json'}
# for date in gold_dates_weekly:
#     conn.request('GET', f'/api/XAU/USD/{date}',payload,headers)
#     res= conn.getresponse()
#     gold_info = res.read()
#     gold_json_bytes = gold_info.decode('utf-8')
#     gold_json = json.loads(gold_json_bytes)
#     weekly_gold_price.append(gold_json['price'])
#     gold_24h_chg_pct.append(gold_json['chp'])

# %%
#combine weekly gold data with weekly crypto data
# cryptogold = {'Date':crypto_weekly_dates, 'BTC_Price':crypto_weekly_prices, 'Gold_Price':weekly_gold_price}
# crypto_v_gold = pd.DataFrame(cryptogold)
# crypto_v_gold

# %%
#crypto_v_gold.to_csv('Crypto_v_Gold.csv')

# %% [markdown]
# EXTRACT INFLATION DATA

# %%
# Query Bureau of Labor Statistics for inflation data
inflation_url = 'https://api.bls.gov/publicAPI/v2/timeseries/data/'
inf = requests.post(inflation_url, data = {'seriesid':'CUUR0000SA0', 'startyear':'2013', 'endyear':'2020',
                                           'catalog':'true', 'calculations':'true', 'aspects':'true', 'registrationkey':{bls_key}})
# inf_data = inf.json()
# inf_data
inf_data = inf.json()
inf_data
# Out:
# {'status': 'REQUEST_SUCCEEDED',
#  'responseTime': 217,
#  'message': ['No Aspect Available for Series CUUR0000SA0',
#   'BLS does not produce net change calculations for Series CUUR0000SA0'],
#  'Results': {'series': [{'seriesID': 'CUUR0000SA0',
#     'catalog': {'series_title': 'All items in U.S. city average, all urban consumers, not seasonally adjusted',
#      'series_id': 'CUUR0000SA0',
#      'seasonality': 'Not Seasonally Adjusted',
#      'survey_name': 'CPI for All Urban Consumers (CPI-U)',
#      'survey_abbreviation': 'CU',
#      'measure_data_type': 'All items',
#      'area': 'U.S. city average',
#      'item': 'All items'},
#     'data': [{'year': '2020',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '260.474',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.1', '3': '0.1', '6': '1.0', '12': '1.4'}}},
#      {'year': '2020',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '260.229',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.1', '3': '0.1', '6': '1.5', '12': '1.2'}}},
#      {'year': '2020',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '260.388',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.0', '3': '0.5', '6': '1.6', '12': '1.2'}}},
#      {'year': '2020',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '260.280',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.1', '3': '1.0', '6': '0.8', '12': '1.4'}}},
#      {'year': '2020',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '259.918',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.3', '3': '1.4', '6': '0.5', '12': '1.3'}}},
#      {'year': '2020',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '259.101',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.5', '3': '1.1', '6': '0.4', '12': '1.0'}}},
#      {'year': '2020',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '257.797',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.5', '3': '-0.1', '6': '0.3', '12': '0.6'}}},
#      {'year': '2020',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '256.394',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.0', '3': '-0.9', '6': '-0.3', '12': '0.1'}}},
#      {'year': '2020',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '256.389',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.7', '3': '-0.6', '6': '-0.4', '12': '0.3'}}},
#      {'year': '2020',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '258.115',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.2', '3': '0.4', '6': '0.5', '12': '1.5'}}},
#      {'year': '2020',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '258.678',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.3', '3': '0.6', '6': '0.8', '12': '2.3'}}},
#      {'year': '2020',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '257.971',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.4', '3': '0.2', '6': '0.5', '12': '2.5'}}},
#      {'year': '2019',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '256.974',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.1', '3': '0.1', '6': '0.3', '12': '2.3'}}},
#      {'year': '2019',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '257.208',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.1', '3': '0.3', '6': '0.4', '12': '2.1'}}},
#      {'year': '2019',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '257.346',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.2', '3': '0.3', '6': '0.7', '12': '1.8'}}},
#      {'year': '2019',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '256.759',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.1', '3': '0.2', '6': '1.0', '12': '1.7'}}},
#      {'year': '2019',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '256.558',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.0', '3': '0.2', '6': '1.5', '12': '1.7'}}},
#      {'year': '2019',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '256.571',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.2', '3': '0.4', '6': '1.9', '12': '1.8'}}},
#      {'year': '2019',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '256.143',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.0', '3': '0.8', '6': '2.0', '12': '1.6'}}},
#      {'year': '2019',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '256.092',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.2', '3': '1.3', '6': '1.6', '12': '1.8'}}},
#      {'year': '2019',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '255.548',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.5', '3': '1.5', '6': '1.1', '12': '2.0'}}},
#      {'year': '2019',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '254.202',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.6', '3': '1.2', '6': '0.7', '12': '1.9'}}},
#      {'year': '2019',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '252.776',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.4', '3': '0.3', '6': '0.2', '12': '1.5'}}},
#      {'year': '2019',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '251.712',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.2', '3': '-0.5', '6': '-0.1', '12': '1.6'}}},
#      {'year': '2018',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '251.233',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.3', '3': '-0.5', '6': '-0.3', '12': '1.9'}}},
#      {'year': '2018',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '252.038',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.3', '3': '0.0', '6': '0.2', '12': '2.2'}}},
#      {'year': '2018',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '252.885',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.2', '3': '0.3', '6': '0.9', '12': '2.5'}}},
#      {'year': '2018',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '252.439',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.1', '3': '0.2', '6': '1.2', '12': '2.3'}}},
#      {'year': '2018',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '252.146',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.1', '3': '0.2', '6': '1.3', '12': '2.7'}}},
#      {'year': '2018',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '252.006',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.0', '3': '0.6', '6': '1.7', '12': '2.9'}}},
#      {'year': '2018',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '251.989',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.2', '3': '1.0', '6': '2.2', '12': '2.9'}}},
#      {'year': '2018',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '251.588',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.4', '3': '1.0', '6': '2.0', '12': '2.8'}}},
#      {'year': '2018',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '250.546',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.4', '3': '1.1', '6': '1.6', '12': '2.5'}}},
#      {'year': '2018',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '249.554',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.2', '3': '1.2', '6': '1.1', '12': '2.4'}}},
#      {'year': '2018',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '248.991',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.5', '3': '0.9', '6': '1.4', '12': '2.2'}}},
#      {'year': '2018',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '247.867',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.5', '3': '0.5', '6': '1.3', '12': '2.1'}}},
#      {'year': '2017',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '246.524',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.1', '3': '-0.1', '6': '0.6', '12': '2.1'}}},
#      {'year': '2017',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '246.669',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.0', '3': '0.5', '6': '0.8', '12': '2.2'}}},
#      {'year': '2017',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '246.663',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.1', '3': '0.8', '6': '0.9', '12': '2.0'}}},
#      {'year': '2017',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '246.819',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.5', '3': '0.8', '6': '1.2', '12': '2.2'}}},
#      {'year': '2017',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '245.519',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.3', '3': '0.3', '6': '0.8', '12': '1.9'}}},
#      {'year': '2017',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '244.786',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.1', '3': '0.1', '6': '0.8', '12': '1.7'}}},
#      {'year': '2017',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '244.955',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.1', '3': '0.5', '6': '1.5', '12': '1.6'}}},
#      {'year': '2017',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '244.733',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.1', '3': '0.5', '6': '1.4', '12': '1.9'}}},
#      {'year': '2017',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '244.524',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.3', '3': '0.7', '6': '1.2', '12': '2.2'}}},
#      {'year': '2017',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '243.801',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.1', '3': '1.0', '6': '1.0', '12': '2.4'}}},
#      {'year': '2017',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '243.603',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.3', '3': '0.9', '6': '1.1', '12': '2.7'}}},
#      {'year': '2017',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '242.839',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.6', '3': '0.5', '6': '0.9', '12': '2.5'}}},
#      {'year': '2016',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '241.432',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.0', '3': '0.0', '6': '0.2', '12': '2.1'}}},
#      {'year': '2016',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '241.353',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.2', '3': '0.2', '6': '0.5', '12': '1.7'}}},
#      {'year': '2016',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '241.729',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.1', '3': '0.5', '6': '1.0', '12': '1.6'}}},
#      {'year': '2016',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '241.428',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.2', '3': '0.2', '6': '1.4', '12': '1.5'}}},
#      {'year': '2016',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '240.849',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.1', '3': '0.3', '6': '1.6', '12': '1.1'}}},
#      {'year': '2016',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '240.628',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.2', '3': '0.6', '6': '1.6', '12': '0.8'}}},
#      {'year': '2016',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '241.018',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.3', '3': '1.2', '6': '1.9', '12': '1.0'}}},
#      {'year': '2016',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '240.229',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.4', '3': '1.3', '6': '1.2', '12': '1.0'}}},
#      {'year': '2016',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '239.261',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.5', '3': '1.0', '6': '0.6', '12': '1.1'}}},
#      {'year': '2016',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '238.132',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.4', '3': '0.7', '6': '0.1', '12': '0.9'}}},
#      {'year': '2016',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '237.111',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.1', '3': '-0.1', '6': '-0.5', '12': '1.0'}}},
#      {'year': '2016',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '236.916',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.2', '3': '-0.4', '6': '-0.7', '12': '1.4'}}},
#      {'year': '2015',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '236.525',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.3', '3': '-0.6', '6': '-0.9', '12': '0.7'}}},
#      {'year': '2015',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '237.336',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.2', '3': '-0.4', '6': '-0.2', '12': '0.5'}}},
#      {'year': '2015',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '237.838',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.0', '3': '-0.3', '6': '0.5', '12': '0.2'}}},
#      {'year': '2015',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '237.945',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.2', '3': '-0.3', '6': '0.8', '12': '0.0'}}},
#      {'year': '2015',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '238.316',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.1', '3': '0.2', '6': '1.5', '12': '0.2'}}},
#      {'year': '2015',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '238.654',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.0', '3': '0.9', '6': '2.1', '12': '0.2'}}},
#      {'year': '2015',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '238.638',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.4', '3': '1.1', '6': '1.6', '12': '0.1'}}},
#      {'year': '2015',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '237.805',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.5', '3': '1.3', '6': '0.7', '12': '0.0'}}},
#      {'year': '2015',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '236.599',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.2', '3': '1.2', '6': '-0.4', '12': '-0.2'}}},
#      {'year': '2015',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '236.119',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.6', '3': '0.6', '6': '-0.8', '12': '-0.1'}}},
#      {'year': '2015',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '234.722',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.4', '3': '-0.6', '6': '-1.3', '12': '0.0'}}},
#      {'year': '2015',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '233.707',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.5', '3': '-1.6', '6': '-1.9', '12': '-0.1'}}},
#      {'year': '2014',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '234.812',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.6', '3': '-1.4', '6': '-1.5', '12': '0.8'}}},
#      {'year': '2014',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '236.151',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.5', '3': '-0.7', '6': '-0.7', '12': '1.3'}}},
#      {'year': '2014',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '237.433',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.3', '3': '-0.3', '6': '0.2', '12': '1.7'}}},
#      {'year': '2014',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '238.031',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.1', '3': '-0.1', '6': '0.7', '12': '1.7'}}},
#      {'year': '2014',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '237.852',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.2', '3': '0.0', '6': '1.3', '12': '1.7'}}},
#      {'year': '2014',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '238.250',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.0', '3': '0.5', '6': '1.9', '12': '2.0'}}},
#      {'year': '2014',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '238.343',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.2', '3': '0.9', '6': '2.3', '12': '2.1'}}},
#      {'year': '2014',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '237.900',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.3', '3': '1.3', '6': '2.1', '12': '2.1'}}},
#      {'year': '2014',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '237.072',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.3', '3': '1.3', '6': '1.5', '12': '2.0'}}},
#      {'year': '2014',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '236.293',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.6', '3': '1.4', '6': '0.9', '12': '1.5'}}},
#      {'year': '2014',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '234.781',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.4', '3': '0.7', '6': '0.4', '12': '1.1'}}},
#      {'year': '2014',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '233.916',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.4', '3': '0.2', '6': '0.1', '12': '1.6'}}},
#      {'year': '2013',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '233.049',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.0', '3': '-0.5', '6': '-0.2', '12': '1.5'}}},
#      {'year': '2013',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '233.069',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.2', '3': '-0.3', '6': '0.1', '12': '1.2'}}},
#      {'year': '2013',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '233.546',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.3', '3': '0.0', '6': '0.4', '12': '1.0'}}},
#      {'year': '2013',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '234.149',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.1', '3': '0.3', '6': '0.6', '12': '1.2'}}},
#      {'year': '2013',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '233.877',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.1', '3': '0.4', '6': '0.7', '12': '1.5'}}},
#      {'year': '2013',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '233.596',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.0', '3': '0.5', '6': '1.4', '12': '2.0'}}},
#      {'year': '2013',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '233.504',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.2', '3': '0.3', '6': '1.7', '12': '1.8'}}},
#      {'year': '2013',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '232.945',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.2', '3': '0.3', '6': '1.2', '12': '1.4'}}},
#      {'year': '2013',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '232.531',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.1', '3': '1.0', '6': '0.5', '12': '1.1'}}},
#      {'year': '2013',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '232.773',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.3', '3': '1.4', '6': '0.6', '12': '1.5'}}},
#      {'year': '2013',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '232.166',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.8', '3': '0.8', '6': '0.8', '12': '2.0'}}},
#      {'year': '2013',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '230.280',
#       'aspects': [],
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.3', '3': '-0.4', '6': '0.5', '12': '1.6'}}}]}]}}

# %%
inf_months = []
inf_year = []
inf_value = []
inf_month_pct_chg = []
for i in range(95):
    inf_months.append(inf_data['Results']['series'][0]['data'][i]['period'])
    inf_year.append(inf_data['Results']['series'][0]['data'][i]['year'])
    inf_value.append(inf_data['Results']['series'][0]['data'][i]['value'])
    inf_month_pct_chg.append(inf_data['Results']['series'][0]['data'][i]['calculations']['pct_changes']['1'])

# %%
#Remove the 'M' in in the string for each month in inf_months
inf_months[:] = [s.replace('M','') for s in inf_months]

# %%
# Concatenate YYYY-MM
inf_year_month = [i + '-' + j for i,j in zip(inf_year, inf_months)]

# %%
# Create lists of monthly Crypto data to merge with monthly inflation data
#inf_year_month
btc_monthly_prices = []
btc_month_end_index = -32
for i in range(8):
    for keyz, valuez in days_per_month.items():
        try:
            btc_monthly_prices.append(btc_prices[btc_month_end_index])
            btc_month_end_index = btc_month_end_index + int(valuez)
        except:
            print(f'no index at {valuez}')

# %%
# btc_monthly_prices.append(crypto_df['BTC Price'][2919])
# btc_monthly_prices.pop(0)
# Out:
# '28986.00603580'

# %%
# btc_monthly_prices.pop(0)
# Out:
# '33099.05748705'

# %%
# Reverse the order of the inflation data
ordered_inf_year_month = []
ordered_inf_value = []
ordered_inf_month_pct_chg = []
inf_months_index = 94
for e in inf_months:
        ordered_inf_year_month.append(inf_year_month[inf_months_index])
        ordered_inf_value.append(inf_value[inf_months_index])
        ordered_inf_month_pct_chg.append(inf_month_pct_chg[inf_months_index])
        inf_months_index = inf_months_index -1

# %%
#Calculate monthly change and monthly change pct for BTC prices
btc_monthly_change = [0]
btc_pct_monthly_change = [0]
btc_change_index = 1
for m in range(94):
        btc_monthly_change.append(float(btc_monthly_prices[btc_change_index])-float(btc_monthly_prices[btc_change_index-1]))
        btc_pct_monthly_change.append(((float(btc_monthly_prices[btc_change_index])-float(btc_monthly_prices[btc_change_index-1]))/
                                     float(btc_monthly_prices[btc_change_index-1])*100))
        btc_change_index=btc_change_index+1

# %%
# Merge crypto data with inflation data, create a dataframe, and crypto/inflation dataframe to CSV
crypto_inflation_data_dict = {'Date':ordered_inf_year_month, 'Inflation Value (1984=100)':ordered_inf_value,
                       'Monthly Change (%)':ordered_inf_month_pct_chg,'BTC_Price':btc_monthly_prices,'BTC_Pct_Change':btc_pct_monthly_change}
crypto_v_inflation = pd.DataFrame(crypto_inflation_data_dict)
crypto_v_inflation.to_csv('Crypto_v_Inflation.csv')

# %% [markdown]
# MERGE CRYPTO DATA WITH UNCERTAINTY DATA

# %%
# Open the uncertainty CSVs as dataframes
import os
twitter = os.path.join("Twitter_Uncertainty.csv")
twitter_uncertainty = pd.read_csv(twitter)
twitter_uncertainty['date'][1122]
# Out:
# '2016-02-28 00:00:00'

# %%
# Calculate raw daily change and percent daily change in btc prices
btc_daily_change = [0]
btc_pct_daily_change = [0]
btc_daily_change_index = 1
for m in range(2919):
        btc_daily_change.append(float(btc_prices[btc_daily_change_index])-float(btc_prices[btc_daily_change_index-1]))
        btc_pct_daily_change.append(((float(btc_prices[btc_daily_change_index])-float(btc_prices[btc_daily_change_index-1]))/
                                     float(btc_prices[btc_daily_change_index-1])*100))
        btc_daily_change_index=btc_daily_change_index+1

# %%
# Create df and export to csv full daily crypto prices with percent change and daily change calculations
crypto_prices_with_chg_dict = {'Date':btc_timestamps,'BTC_Price':btc_prices,'BTC_Change':btc_daily_change, 'BTC_pct_Change':btc_pct_daily_change}
crypto_prices_with_chg = pd.DataFrame(crypto_prices_with_chg_dict)
crypto_prices_with_chg.to_csv("Crypto_Prices_with_Change.csv")

# %%
# Create dataframe with dates, crypto prices, crypto changes, Twitter uncertainty
twitter_uncertainty_index = twitter_uncertainty['TEU']
short_crypto_dates = btc_timestamps[:2782]
short_crypto_prices = btc_prices[:2782]
short_btc_change = btc_daily_change[:2782]
short_btc_pct_change = btc_pct_daily_change[:2782]
crypto_v_twitter_dict = {'Date':short_crypto_dates, 'BTC_Price':short_crypto_prices,'BTC_Change':short_btc_change,
                         'BTC_pct_Change':short_btc_pct_change,'TEU':twitter_uncertainty_index}
crypto_v_twitter = pd.DataFrame(crypto_v_twitter_dict)
crypto_v_twitter.to_csv('Crypto_v_Twitter.csv')

# %%
# Open Categorical Uncertainty Data
unc_path = os.path.join("Categorical_EPU_Data.csv")
cat_uncertainty = pd.read_csv(unc_path)

# %%
cat_uncertainty=cat_uncertainty.drop(index=0)

# %%
cat_uncertainty['BTC_Price'] = btc_monthly_prices
cat_uncertainty['BTC_Pct_Change'] = btc_pct_monthly_change
cat_uncertainty.to_csv('Crypto_v_Uncertainty.csv')

# %%
golden_road = os.path.join("Crypto_v_Gold.csv")
gooollld = pd.read_csv(golden_road)

# %%
gold_weekly_prices = gooollld['Gold_Price']
crypto_gold_datez = gooollld['Date']

# %%
#Calculate btc weekly change, btc weekly change pct, gold weekly change, gold weekly change pct
btc_wkly_change = [0]
btc_pct_wkly_change = [0]
gold_wkly_change = [0]
gold_pct_wkly_change = [0]
gold_wkly_change_index = 1
for m in range(416):
        btc_wkly_change.append(float(crypto_weekly_prices[gold_wkly_change_index])-float(crypto_weekly_prices[gold_wkly_change_index-1]))
        btc_pct_wkly_change.append(((float(crypto_weekly_prices[gold_wkly_change_index])-float(crypto_weekly_prices[gold_wkly_change_index-1]))/
                                     float(crypto_weekly_prices[gold_wkly_change_index-1])*100))
        gold_wkly_change.append(float(gold_weekly_prices[gold_wkly_change_index])-float(gold_weekly_prices[gold_wkly_change_index-1]))
        gold_pct_wkly_change.append(((float(gold_weekly_prices[gold_wkly_change_index])-float(gold_weekly_prices[gold_wkly_change_index-1]))/
                                     float(gold_weekly_prices[gold_wkly_change_index-1])*100))
        gold_wkly_change_index=gold_wkly_change_index+1

# %%
gooollld['BTC_Change']=btc_wkly_change
gooollld['BTC_pct_Change'] = btc_pct_wkly_change
gooollld['Gold_Change'] = gold_wkly_change
gooollld['Gold_pct_Change'] = gold_pct_wkly_change
gooollld.to_csv("btc_v_gold.csv")
# btc_v_gold_dict = {'Date':crypto_gold_datez,'BTC_Price':}

# %% [markdown]
# MERGE STOCK DATA WITH CRYPTO DATA

# %%
stock_path = os.path.join("Stock_Market_Data.csv")
stock_data = pd.read_csv(stock_path)
crypto_v_stockmarket = stock_data.merge(crypto_v_twitter, how='inner', on='Date')
crypto_v_stockmarket = crypto_v_stockmarket.drop(columns='TEU')
crypto_v_stockmarket.to_csv("crypto_v_stockmarket.csv")

# %%
cat_uncertainty
# Out:
#          Date  Economic Policy Uncertainty  Monetary policy  \
# 1    3/1/2013                   127.907071        74.678109
# 2    4/1/2013                    77.201711        34.016665
# 3    5/1/2013                    71.645563        35.081088
# 4    6/1/2013                    77.763068        55.337061
# 5    7/1/2013                    86.720342        51.459549
# ..        ...                          ...              ...
# 91   9/1/2020                   225.148692       124.028643
# 92  10/1/2020                   255.857027       108.102130
# 93  11/1/2020                   252.119123       146.897536
# 94  12/1/2020                   224.380454        80.474777
# 95   1/1/2021                   208.532713        71.279622
#
#     Government spending  National security  Financial Regulation  \
# 1            261.072394          67.232097             76.095169
# 2             72.652522          38.559536             47.961099
# 3             53.429494          31.160853             37.286633
# 4             57.108591          36.726217             89.548832
# 5             71.349203          91.145834            153.359947
# ..                  ...                ...                   ...
# 91            97.974717         137.845947            102.927451
# 92           119.907785          95.426135            136.676648
# 93           147.805234         169.058055            101.620142
# 94           154.953537          70.908410             36.542788
# 95           118.186977         125.025667             79.244228
#
#     Sovereign debt, currency crises       BTC_Price  BTC_Pct_Change
# 1                        243.156035     33.85347654        0.000000
# 2                         28.380715     93.79780464      177.069933
# 3                         27.580198    139.88375302       49.133291
# 4                         38.213961    127.94651362       -8.533685
# 5                         15.468733     89.73516147      -29.865098
# ..                              ...             ...             ...
# 91                       137.040186  11670.62656357        2.793402
# 92                        75.822797  10784.41101995       -7.593556
# 93                        71.210317  13893.46573199       28.829156
# 94                        34.752845  19531.16867786       40.578089
# 95                        12.560446  33099.05748705       69.467880
#
# [95 rows x 9 columns]

# %%
crypto_v_twitter
# Out:
#             Date       BTC_Price  BTC_Change  BTC_pct_Change         TEU
# 0     2013-02-01     20.56073352    0.000000        0.000000  101.457894
# 1     2013-02-02     19.98875651   -0.571977       -2.781890   26.352700
# 2     2013-02-03     20.74686364    0.758107        3.792668   27.670335
# 3     2013-02-04     20.52266187   -0.224202       -1.080654   80.375734
# 4     2013-02-05     20.76371547    0.241054        1.174573   94.869719
# ...          ...             ...         ...             ...         ...
# 2777  2020-09-11  10422.24255140   14.065334        0.135137  260.891728
# 2778  2020-09-12  10467.73825792   45.495707        0.436525  150.210389
# 2779  2020-09-13  10367.46538855 -100.272869       -0.957923  142.304579
# 2780  2020-09-14  10688.95501140  321.489623        3.100947  304.373683
# 2781  2020-09-15  10838.76381266  149.808801        1.401529  347.855637
#
# [2782 rows x 5 columns]

# %%
crypto_v_inflation
# Out:
#        Date Inflation Value (1984=100) Monthly Change (%)       BTC_Price  \
# 0   2013-02                    232.166                0.8     33.85347654
# 1   2013-03                    232.773                0.3     93.79780464
# 2   2013-04                    232.531               -0.1    139.88375302
# 3   2013-05                    232.945                0.2    127.94651362
# 4   2013-06                    233.504                0.2     89.73516147
# ..      ...                        ...                ...             ...
# 90  2020-08                    259.918                0.3  11670.62656357
# 91  2020-09                    260.280                0.1  10784.41101995
# 92  2020-10                    260.388                0.0  13893.46573199
# 93  2020-11                    260.229               -0.1  19531.16867786
# 94  2020-12                    260.474                0.1  33099.05748705
#
#     BTC_Pct_Change
# 0         0.000000
# 1       177.069933
# 2        49.133291
# 3        -8.533685
# 4       -29.865098
# ..             ...
# 90        2.793402
# 91       -7.593556
# 92       28.829156
# 93       40.578089
# 94       69.467880
#
# [95 rows x 5 columns]

# %%
gooollld
# Out:
#            Date     BTC_Price  Gold_Price   BTC_Change  BTC_pct_Change  \
# 0      2/1/2013     20.560734     1665.00     0.000000        0.000000
# 1      2/8/2013     22.888735     1669.75     2.328001       11.322559
# 2     2/15/2013     27.502657     1629.25     4.613922       20.158048
# 3     2/22/2013     30.706054     1580.00     3.203398       11.647593
# 4      3/1/2013     34.944449     1570.00     4.238395       13.803124
# ..          ...           ...         ...          ...             ...
# 412  12/27/2020  26310.707720     1872.55  3220.537366       13.657307
# 413    1/3/2021  33117.849620     1891.10  5235.270774       19.533431
# 414   1/10/2021  38363.108450     1891.30  5559.165851       17.352403
# 415   1/17/2021  35829.897020     1853.85 -1774.059251       -4.718741
# 416   1/24/2021  32316.993880     1853.60 -3456.227021       -9.648344
#
#      Gold_Change  Gold_pct_Change
# 0           0.00         0.000000
# 1           4.75         0.285285
# 2         -40.50        -2.425513
# 3         -49.25        -3.022863
# 4         -10.00        -0.632911
# ..           ...              ...
# 412        -6.40        -0.340616
# 413        18.55         0.990628
# 414         0.20         0.010576
# 415       -37.45        -1.980119
# 416        -0.25        -0.013485
#
# [417 rows x 7 columns]

# %%
crypto_v_stockmarket
# Out:
#             Date   DJIA_Close  DJIA_Change  DJIA_pct_Change     Close  \
# 0     2013-02-01     14009.79         0.00         0.000000   3179.10
# 1     2013-02-04     13880.08      -129.71        -0.925853   3131.17
# 2     2013-02-05     13979.30        99.22         0.714837   3171.58
# 3     2013-02-06     13986.52         7.22         0.051648   3168.48
# 4     2013-02-07     13944.05       -42.47        -0.303650   3165.13
# ...          ...          ...          ...              ...       ...
# 1913  2020-09-09     27940.47       439.58         1.598421  11141.56
# 1914  2020-09-10     27534.58      -405.89        -1.452696  10919.59
# 1915  2020-09-11     27665.64       131.06         0.475983  10853.55
# 1916  2020-09-14     27993.33       327.69         1.184466  11056.65
# 1917  2020-09-15     27995.60         2.27         0.008109  11190.32
#
#       NDAQ_Change  NDAQ_pct_Change       BTC_Price  BTC_Change  BTC_pct_Change
# 0            0.00         0.000000     20.56073352    0.000000        0.000000
# 1          -47.93        -0.015077     20.52266187   -0.224202       -1.080654
# 2           40.41         0.012906     20.76371547    0.241054        1.174573
# 3           -3.10        -0.000977     21.27228065    0.508565        2.449298
# 4           -3.35        -0.001057     22.14472461    0.872444        4.101318
# ...           ...              ...             ...         ...             ...
# 1913       293.87         0.027091  10264.65200779   69.980012        0.686437
# 1914      -221.97        -0.019923  10408.17721691  143.525209        1.398247
# 1915       -66.04        -0.006048  10422.24255140   14.065334        0.135137
# 1916       203.10         0.018713  10688.95501140  321.489623        3.100947
# 1917       133.67         0.012090  10838.76381266  149.808801        1.401529
#
# [1918 rows x 10 columns]
